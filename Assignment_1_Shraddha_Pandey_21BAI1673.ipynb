# %% [markdown]
# # AI ML ASSIGNMENT 1
# ### **Shraddha Pandey 21BAI1673**
# VIT Chennai

# %%
import pandas as pd
import numpy as np

# %%
#task - 1
np.random.seed()
data = np.random.rand(4,4)
df = pd.DataFrame(data)
df
# Out:
#           0         1         2         3
# 0  0.666549  0.671907  0.429151  0.759203
# 1  0.012551  0.113870  0.733366  0.004845
# 2  0.966381  0.109338  0.369363  0.945544
# 3  0.583961  0.978057  0.631788  0.932926

# %%
#task - 2
df = pd.DataFrame(data, columns=['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4', ])
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.666549        0.671907        0.429151        0.759203
# 1        0.012551        0.113870        0.733366        0.004845
# 2        0.966381        0.109338        0.369363        0.945544
# 3        0.583961        0.978057        0.631788        0.932926

# %%
#task - 3
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.557361        0.468293        0.540917        0.660630
# std          0.398642        0.430419        0.170506        0.445380
# min          0.012551        0.109338        0.369363        0.004845
# 25%          0.441109        0.112737        0.414204        0.570614
# 50%          0.625255        0.392889        0.530470        0.846065
# 75%          0.741507        0.748445        0.657182        0.936080
# max          0.966381        0.978057        0.733366        0.945544

# %%
#task - 4
df.isnull().sum()
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
#task - 4 contd.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      float64
#  1   Random value 2  4 non-null      float64
#  2   Random value 3  4 non-null      float64
#  3   Random value 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes

# %%
#task - 5
df.loc[:, ['Random value 2', 'Random value 3']]
# Out:
#    Random value 2  Random value 3
# 0        0.671907        0.429151
# 1        0.113870        0.733366
# 2        0.109338        0.369363
# 3        0.978057        0.631788

# %%
#task - 5 contd.
df.iloc[:, [1,2]]
# Out:
#    Random value 2  Random value 3
# 0        0.671907        0.429151
# 1        0.113870        0.733366
# 2        0.109338        0.369363
# 3        0.978057        0.631788
